# %% [markdown]
# <a href="https://colab.research.google.com/github/freddy-7/1N1002B_2023/blob/main/1_Extracci%C3%B3n_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Convertir en dataframe
df = pd.read_csv("CountryTable.csv")
#df

# %%
#Imprimimos las primeras filas o registros del Dataframe
df.head(5)
# Out:
#               code         name                     region  surface_area  \
# continent
# North America  ABW        Aruba                  Caribbean         193.0
# Asia           AFG  Afghanistan  Southern and Central Asia      652090.0
# Africa         AGO       Angola             Central Africa     1246700.0
# North America  AIA     Anguilla                  Caribbean          96.0
# Europe         ALB      Albania            Southern Europe       28748.0
#
#                independence_year  population  life_expectancy     gnp  \
# continent
# North America                NaN      103000             78.4   828.0
# Asia                      1919.0    22720000             45.9  5976.0
# Africa                    1975.0    12878000             38.3  6648.0
# North America                NaN        8000             76.1    63.2
# Europe                    1912.0     3401200             71.6  3205.0
#
#                gnp_old             local_name  \
# continent
# ...

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUALITATIVAS **

# %%
#Filtro por objeto
filtro1=df[df["region"] == "Central Africa"]
filtro1
# Out:
#     code                                   name continent          region  \
# 2    AGO                                 Angola    Africa  Central Africa
# 36   CAF               Central African Republic    Africa  Central Africa
# 43   CMR                               Cameroon    Africa  Central Africa
# 44   COD  Congo, The Democratic Republic of the    Africa  Central Africa
# 45   COG                                  Congo    Africa  Central Africa
# 75   GAB                                  Gabon    Africa  Central Africa
# 84   GNQ                      Equatorial Guinea    Africa  Central Africa
# 196  STP                  Sao Tome and Principe    Africa  Central Africa
# 205  TCD                                   Chad    Africa  Central Africa
#
#      surface_area  independence_year  population  life_expectancy     gnp  \
# 2       1246700.0             1975.0    12878000             38.3  6648.0
# 36       622984.0             1960.0     3615000             44.0  1054.0
# ...

# %%
#Filtro por filas
#filtro2= df.iloc[300:302,: ]
filtro2=df.iloc[ 10:16 , : ]  #filas no consecutivas
filtro2
# Out:
#    code                         name      continent  \
# 10  ASM               American Samoa        Oceania
# 11  ATA                   Antarctica     Antarctica
# 12  ATF  French Southern territories     Antarctica
# 13  ATG          Antigua and Barbuda  North America
# 14  AuS                    Australia        Oceania
# 15  AuT                      Austria         Europe
#
#                        region  surface_area  independence_year  population  \
# 10                  Polynesia         199.0                NaN       68000
# 11                 Antarctica    13120000.0                NaN           0
# 12                 Antarctica        7780.0                NaN           0
# 13                  Caribbean         442.0             1981.0       68000
# 14  Australia and New Zealand     7741220.0             1901.0    18886000
# 15             Western Europe       83859.0             1918.0     8091800
#
# ...

# %%
#Filtro por columnas
filtro3=df.iloc[ : , 4:7]
#filtro3=df.iloc[ : , [3,4,6]]  #columnas no consecutivas
filtro3
# Out:
#                independence_year  population  life_expectancy
# continent
# North America                NaN      103000             78.4
# Asia                      1919.0    22720000             45.9
# Africa                    1975.0    12878000             38.3
# North America                NaN        8000             76.1
# Europe                    1912.0     3401200             71.6
# ...                          ...         ...              ...
# Asia                      1918.0    18112000             59.8
# Europe                    1918.0    10640000             72.4
# Africa                    1910.0    40377000             51.1
# Africa                    1964.0     9169000             37.2
# Africa                    1980.0    11669000             37.8
#
# [239 rows x 3 columns]

# %%
df= pd.read_csv("file.csv", index_col=2)
df
# Out:
#               code          name                     region  surface_area  \
# continent
# North America  ABW         Aruba                  Caribbean         193.0
# Asia           AFG   Afghanistan  Southern and Central Asia      652090.0
# Africa         AGO        Angola             Central Africa     1246700.0
# North America  AIA      Anguilla                  Caribbean          96.0
# Europe         ALB       Albania            Southern Europe       28748.0
# ...            ...           ...                        ...           ...
# Asia           YEM         Yemen                Middle East      527968.0
# Europe         YuG    Yugoslavia            Southern Europe      102173.0
# Africa         ZAF  South Africa            Southern Africa     1221037.0
# Africa         ZMB        Zambia             Eastern Africa      752618.0
# Africa         ZWE      Zimbabwe             Eastern Africa      390757.0
#
# ...

# %%
#Paso 2: Aplicamos Filtro de filas vs columnas
filtro4=df.loc[["Africa","Asia"], ["population"]]
filtro4
# Out:
#            population
# continent
# Africa       12878000
# Africa        6695000
# Africa        6097000
# Africa       11937000
# Africa        1622000
# ...               ...
# Asia         66591000
# Asia         22256000
# Asia         24318000
# Asia         79832000
# Asia         18112000
#
# [109 rows x 1 columns]

# %%
#Filtro por cabecera
filtro5=df.head(10)
filtro5
# Out:
#               code                  name                     region  \
# continent
# North America  ABW                 Aruba                  Caribbean
# Asia           AFG           Afghanistan  Southern and Central Asia
# Africa         AGO                Angola             Central Africa
# North America  AIA              Anguilla                  Caribbean
# Europe         ALB               Albania            Southern Europe
# Europe         AND               Andorra            Southern Europe
# North America  ANT  Netherlands Antilles                  Caribbean
# Asia           ARE  united Arab Emirates                Middle East
# South America  ARG             Argentina              South America
# Asia           ARM               Armenia                Middle East
#
#                surface_area  independence_year  population  life_expectancy  \
# continent
# North America         193.0                NaN      103000             78.4
# ...

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUANTITATIVAS**

# %%
#Filtro por comparacion
filtro6=df[df["independence_year"] > 1900]
filtro6
# Out:
#           code                  name                     region  surface_area  \
# continent
# Asia       AFG           Afghanistan  Southern and Central Asia      652090.0
# Africa     AGO                Angola             Central Africa     1246700.0
# Europe     ALB               Albania            Southern Europe       28748.0
# Asia       ARE  united Arab Emirates                Middle East       83600.0
# Asia       ARM               Armenia                Middle East       29800.0
# ...        ...                   ...                        ...           ...
# Asia       YEM                 Yemen                Middle East      527968.0
# Europe     YuG            Yugoslavia            Southern Europe      102173.0
# Africa     ZAF          South Africa            Southern Africa     1221037.0
# Africa     ZMB                Zambia             Eastern Africa      752618.0
# Africa     ZWE              Zimbabwe             Eastern Africa      390757.0
#
# ...

# %% [markdown]
# **FILTROS BASICOS CON CONETORES LOGICOS**

# %%
#Filtro Y
filtro7=df[(df["independence_year"] > 1900) & (df["region"] == "Central Africa")]
filtro7
# Out:
#           code                                   name          region  \
# continent
# Africa     AGO                                 Angola  Central Africa
# Africa     CAF               Central African Republic  Central Africa
# Africa     CMR                               Cameroon  Central Africa
# Africa     COD  Congo, The Democratic Republic of the  Central Africa
# Africa     COG                                  Congo  Central Africa
# Africa     GAB                                  Gabon  Central Africa
# Africa     GNQ                      Equatorial Guinea  Central Africa
# Africa     STP                  Sao Tome and Principe  Central Africa
# Africa     TCD                                   Chad  Central Africa
#
#            surface_area  independence_year  population  life_expectancy  \
# continent
# Africa        1246700.0             1975.0    12878000             38.3
# Africa         622984.0             1960.0     3615000             44.0
# ...

# %%
#Filtro o
filtro8=df[(df["independence_year"] > 1900) | (df["region"] == "Central Africa")]
filtro8
# Out:
#           code                  name                     region  surface_area  \
# continent
# Asia       AFG           Afghanistan  Southern and Central Asia      652090.0
# Africa     AGO                Angola             Central Africa     1246700.0
# Europe     ALB               Albania            Southern Europe       28748.0
# Asia       ARE  united Arab Emirates                Middle East       83600.0
# Asia       ARM               Armenia                Middle East       29800.0
# ...        ...                   ...                        ...           ...
# Asia       YEM                 Yemen                Middle East      527968.0
# Europe     YuG            Yugoslavia            Southern Europe      102173.0
# Africa     ZAF          South Africa            Southern Africa     1221037.0
# Africa     ZMB                Zambia             Eastern Africa      752618.0
# Africa     ZWE              Zimbabwe             Eastern Africa      390757.0
#
# ...

# %%
#Filtro not
filtro9=df[~(df["independence_year"] >= 1900) & ~(df["region"] == "Central Africa")]
filtro9
# Out:
#               code                     name           region  surface_area  \
# continent
# North America  ABW                    Aruba        Caribbean         193.0
# North America  AIA                 Anguilla        Caribbean          96.0
# Europe         AND                  Andorra  Southern Europe         468.0
# North America  ANT     Netherlands Antilles        Caribbean         800.0
# South America  ARG                Argentina    South America     2780400.0
# ...            ...                      ...              ...           ...
# North America  uSA            united States    North America     9363520.0
# South America  VEN                Venezuela    South America      912050.0
# North America  VGB  Virgin Islands, British        Caribbean         151.0
# North America  VIR     Virgin Islands, u.S.        Caribbean         347.0
# Oceania        WLF        Wallis and Futuna        Polynesia         200.0
#
# ...

# %%
#Convertir archivo filtrado a CSV
filtro9.to_csv("Entregable1.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files


files.download("Entregable1.csv")
